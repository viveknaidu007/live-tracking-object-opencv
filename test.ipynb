# %%
import cv2
import pandas as pd
import numpy as np
from ultralytics import YOLO
import cvzone
from vidgear.gears import CamGear
from tracker import*
model=YOLO('yolov8s.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|██████████| 21.5M/21.5M [00:05<00:00, 4.09MB/s]

# %%
#here we have to install pip install yt_dlp for youtube stream mode video to acces

stream = CamGear(source='https://www.youtube.com/watch?v=En_3pkxIJRM', stream_mode = True, logging=True).start() # YouTube Video URL as input
# Out:
# 22:06:18 ::    Helper     ::   INFO   :: Running VidGear Version: 0.3.2
# 22:06:18 ::    Helper     :: WARNING  :: GStreamer not found!
# 22:06:18 ::    Helper     ::  DEBUG   :: Selecting `best` resolution for streams.
# 22:06:18 ::    CamGear    ::   INFO   :: Verifying Streaming URL using yt-dlp backend. Please wait...
# 22:06:21 ::    CamGear    ::   INFO   :: [Backend] :: Streaming URL is fully supported. Available Streams are: [144p, 240p, 360p, 480p, 720p, 1080p, best, worst]
# 22:06:21 ::    CamGear    :: WARNING  :: Livestream URL detected. It is advised to use GStreamer backend(`cv2.CAP_GSTREAMER`) with it.
# 22:06:21 ::    CamGear    ::  DEBUG   :: Using `best` resolution for streaming.
# 22:06:21 ::    CamGear    ::  DEBUG   :: YouTube source ID: `En_3pkxIJRM`, Title: `Усть-Кут Live - Пешеход ст.Лена 2024-01-20 22:06`, Quality: `best`
# 22:06:21 ::    CamGear    ::  DEBUG   :: Enabling Threaded Queue Mode for the current video source!

# %%
def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE :  
        colorsBGR = [x, y]
        print(colorsBGR)
        

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)




my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")
#print(class_list)
count=0
tracker =Tracker()


while True:    
    frame = stream.read()   
    count += 1
    if count % 2 != 0:
        continue


    frame=cv2.resize(frame,(1020,500))

    results=model.predict(frame)
 #   print(results)
    a=results[0].boxes.data
    px=pd.DataFrame(a).astype("float")
#    print(px)
    list=[]
    for index,row in px.iterrows():
#        print(row)
 
        x1=int(row[0])
        y1=int(row[1])
        x2=int(row[2])
        y2=int(row[3])
        d=int(row[5])
        c=class_list[d]
        if 'car' in c:
            list.append([x1,y1,x2,y2])
    bbox_idx=tracker.update(list)
    for bbox in bbox_idx:
        x3,y3,x4,y4,id1=bbox
        cx=int(x3+x4)//2
        cy=int(y3+y4)//2
       
        cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
        cv2.rectangle(frame,(x3,y3),(x4,y4),(255,255,255),2) 
        cvzone.putTextRect(frame,f'{id1}',(x3,y3),1,1)
                 
   


    cv2.imshow("RGB", frame)
    

    if cv2.waitKey(1)&0xFF==27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 1 person, 1 car, 2 trucks, 117.4ms
# Speed: 3.5ms preprocess, 117.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 103.3ms
# Speed: 3.0ms preprocess, 103.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 96.1ms
# Speed: 1.0ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 91.8ms
# Speed: 2.2ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 bus, 2 trucks, 93.0ms
# Speed: 2.3ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 101.0ms
# Speed: 2.1ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 105.7ms
# Speed: 2.1ms preprocess, 105.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 99.7ms
# Speed: 2.0ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 100.8ms
# Speed: 2.0ms preprocess, 100.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 3 trucks, 97.3ms
# Speed: 2.0ms preprocess, 97.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 98.4ms
# Speed: 2.0ms preprocess, 98.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 103.6ms
# Speed: 2.4ms preprocess, 103.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 95.4ms
# Speed: 2.3ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 bus, 1 truck, 95.5ms
# Speed: 1.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 95.1ms
# Speed: 2.5ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 99.4ms
# Speed: 3.4ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 95.2ms
# Speed: 2.3ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 93.9ms
# Speed: 3.1ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 107.6ms
# Speed: 3.0ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 92.9ms
# Speed: 2.0ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 92.6ms
# Speed: 3.0ms preprocess, 92.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 91.4ms
# Speed: 2.2ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 93.7ms
# Speed: 2.4ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 97.8ms
# Speed: 2.0ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [732, 400]
#
# 0: 320x640 1 car, 1 truck, 97.4ms
# Speed: 2.4ms preprocess, 97.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [710, 252]
#
# 0: 320x640 1 car, 1 truck, 94.3ms
# Speed: 2.4ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 truck, 92.1ms
# Speed: 1.0ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 91.9ms
# Speed: 1.0ms preprocess, 91.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 93.6ms
# Speed: 3.0ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 93.7ms
# Speed: 1.3ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [769, 100]
#
# 0: 320x640 1 person, 1 car, 1 truck, 92.3ms
# Speed: 2.0ms preprocess, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [788, 63]
#
# 0: 320x640 1 person, 1 car, 1 truck, 94.1ms
# Speed: 2.1ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 truck, 93.9ms
# Speed: 1.0ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 98.7ms
# Speed: 2.5ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [886, 33]
#
# 0: 320x640 1 person, 1 car, 2 trucks, 95.7ms
# Speed: 1.0ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [947, 19]
#
# 0: 320x640 1 person, 1 car, 2 trucks, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [957, 17]
#
# 0: 320x640 1 car, 2 trucks, 92.2ms
# Speed: 2.0ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [958, 15]
#
# 0: 320x640 1 car, 2 trucks, 92.4ms
# Speed: 2.5ms preprocess, 92.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [983, 4]
#
# 0: 320x640 1 person, 2 cars, 2 trucks, 95.2ms
# Speed: 1.0ms preprocess, 95.2ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 trucks, 94.6ms
# Speed: 2.1ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 trucks, 93.6ms
# Speed: 2.0ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 trucks, 90.5ms
# Speed: 2.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 2 trucks, 90.1ms
# Speed: 2.0ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 92.6ms
# Speed: 2.0ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 109.3ms
# Speed: 3.2ms preprocess, 109.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 trucks, 101.2ms
# Speed: 2.2ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 2 trucks, 90.9ms
# Speed: 2.0ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 trucks, 91.9ms
# Speed: 2.0ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 trucks, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 trucks, 97.2ms
# Speed: 2.0ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 trucks, 97.0ms
# Speed: 2.1ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 trucks, 99.2ms
# Speed: 3.0ms preprocess, 99.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 102.4ms
# Speed: 2.0ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 93.2ms
# Speed: 3.0ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 92.6ms
# Speed: 2.0ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 94.3ms
# Speed: 2.6ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 96.3ms
# Speed: 3.0ms preprocess, 96.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 94.2ms
# Speed: 2.0ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 97.3ms
# Speed: 2.2ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 95.1ms
# Speed: 3.0ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 96.7ms
# Speed: 2.0ms preprocess, 96.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 1 traffic light, 95.7ms
# Speed: 3.0ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 trucks, 1 traffic light, 96.8ms
# Speed: 2.0ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 trucks, 98.1ms
# Speed: 1.0ms preprocess, 98.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 trucks, 99.0ms
# Speed: 2.1ms preprocess, 99.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 trucks, 102.4ms
# Speed: 2.6ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 trucks, 95.0ms
# Speed: 2.0ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 trucks, 94.6ms
# Speed: 2.0ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 106.3ms
# Speed: 1.5ms preprocess, 106.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 97.7ms
# Speed: 2.4ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 93.6ms
# Speed: 2.0ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 trucks, 93.7ms
# Speed: 2.0ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 truck, 1 traffic light, 99.9ms
# Speed: 2.1ms preprocess, 99.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 truck, 1 traffic light, 92.4ms
# Speed: 2.0ms preprocess, 92.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 30
#      25        continue
#      28    frame=cv2.resize(frame,(1020,500))
# ---> 30    results=model.predict(frame)
#      31 #   print(results)
#      32    a=results[0].boxes.data
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\engine\model.py:274, in Model.predict(self, source, stream, predictor, **kwargs)
#     272 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     273     self.predictor.set_prompts(prompts)
# --> 274 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\engine\predictor.py:204, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     202     return self.stream_inference(source, model, *args, **kwargs)
#     203 else:
# --> 204     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\engine\predictor.py:283, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     281 # Inference
#     282 with profilers[1]:
# --> 283     preds = self.inference(im, *args, **kwargs)
#     284     if self.args.embed:
#     285         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\engine\predictor.py:140, in BasePredictor.inference(self, im, *args, **kwargs)
#     134 """Runs inference on a given image using the specified model and arguments."""
#     135 visualize = (
#     136     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     137     if self.args.visualize and (not self.source_type.tensor)
#     138     else False
#     139 )
# --> 140 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\nn\autobackend.py:384, in AutoBackend.forward(self, im, augment, visualize, embed)
#     381     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     383 if self.pt or self.nn_module:  # PyTorch
# --> 384     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     385 elif self.jit:  # TorchScript
#     386     y = self.model(im)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\nn\tasks.py:80, in BaseModel.forward(self, x, *args, **kwargs)
#      78 if isinstance(x, dict):  # for cases of training and validating while training.
#      79     return self.loss(x, *args, **kwargs)
# ---> 80 return self.predict(x, *args, **kwargs)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\nn\tasks.py:98, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#      96 if augment:
#      97     return self._predict_augment(x)
# ---> 98 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\nn\tasks.py:119, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     117 if profile:
#     118     self._profile_one_layer(m, x, dt)
# --> 119 x = m(x)  # run
#     120 y.append(x if m.i in self.save else None)  # save output
#     121 if visualize:
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
